# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

# %%
G = nx.gnm_random_graph(10, 24)

# %%
f = np.random.randint(30, size=10)
for node in G.nodes:
    G.nodes[node]['f'] = f[node]

# %%
nx.draw_random(G, with_labels=False)

# %%
def get_variations(G):
